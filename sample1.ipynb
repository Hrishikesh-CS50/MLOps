# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create a simple plot
x = [1, 2, 3, 4, 5, 6]
y = [2, 3, 5, 7, 11, 13]    
plt.plot(x, y)
plt.title('Simple Plot')    
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
